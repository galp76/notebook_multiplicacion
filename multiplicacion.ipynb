# %% [markdown]
# ## Hola Germán
# Este se usa igual que el otro, dale a RUN para ejecutar el programa

# %%
def formato(y):
    print(a.rjust(15, ' ')+' * '+b)
    print(('-'*(long_a+long_b+3)).rjust((18+long_b)))
    for k in range(l+1):
        y=rstd[k]
        print(y.rjust(15-k, ' '))
    print(rstd)
    print('Presiona ENTER para continuar')
    q=input()

def multiplicar(x, y):
    global llvm, f0, f1, resultado, l 
    for j in range(1, long_b+1):
        llvm=0
        resultado=''
        if l>0:
            rstd.append('')
        for i in range(1, long_a+1):
            c=int(x[long_a-i])*int(y[long_b-j])
            d=str(c)
            g=c+llvm 
            h=str(g)
            if len(d)==2:
                f1=h[1]
                f0=h[0]
            else:
                f1=h 
                f0='0'
            print('Cuanto es '+x[long_a-i]+' multiplicado por '+y[long_b-j]+'?')
            resp=input()
            while resp!=d:
                print('Respuesta incorrecta, por favor introduce el número correcto...')
                resp=input()
            if i==long_a:
                print('Correcto... y '+str(llvm)+' que llevamos son '+h+'\n\nComo es el último número de la izquierda ponemos el '+h+' completo')
                resultado=f0+f1+resultado 
            else:
                print('\nCorrecto... y '+str(llvm)+' que llevamos son '+h+'\n\nPonemos el '+f1+' y llevamos '+f0)
                resultado=f1+resultado 
            rstd[l]=resultado 
            llvm=int(f0)
            formato(rstd[l])
        l=l+1

def sumatoria():
    global smtr, rstd, suma_total
    for i in range(len(rstd)-1):
        smtr.append('')
    for i in range(len(rstd)):
        smtr[i]=rstd[i]+'0'*i 
    for i in range(len(smtr)):
        suma_total=suma_total+int(smtr[i])
        

print('Hola Germán, vamos a hacer tareas!!!\n\nPor favor introduce el primer número:')
a=input()
long_a=len(a)
print('\nAhora introduce el segundo número:')
b=input()
long_b=len(b)
print('Vamos a hacer la siguiente multiplicación:\n')
print(a.rjust(15, ' ')+' * '+b)
print(('-'*(long_a+long_b+3)).rjust((18+long_b)))
print('\nPresiona ENTER para continuar.')
q=input()
rstd=['']
llvm=0
f0=''
f1=''
l=0
resultado=''
smtr=['']
suma_total=0
multiplicar(a, b)
if long_b>1:
    print('Muy bien... para terminar nos toca sumar...')
    sumatoria()
    print('Y el resultado final es '+str(suma_total))
else:
    print('El resultado final es '+rstd[0])
